# %% [markdown]
# <a href="https://colab.research.google.com/github/aarya078/July26/blob/main/Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as pd
name = ["a","b"]
df = pd.Series(name)
print(df)
# Out:
# 0    a
# 1    b
# dtype: object

# %%
#importing csv
df = pd.read_csv("Zomato-data-.csv")
#performing operations

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.sample() # provides any random data which can be provided in braces
# each time the data being chosen gets changed
# Out:
#               name online_order book_table   rate  votes  \
# 119  K27 - The Pub           No         No  3.1/5     30
#
#      approx_cost(for two people) listed_in(type)
# 119                          900          Dining

# %%
df.shape # used too calculate total rows and columns
# Out:
# (148, 7)

# %%
df.dtypes # provides datatype of each column
# Out:
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# approx_cost(for two people)     int64
# listed_in(type)                object
# dtype: object

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
df.info() #analyzes complete set of data provided
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df.describe() #
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
df["name"] #describing a particular column
df[["rate","name"]] # for multiple columns use double[]
#additional usage of features
#checking specific comparison results
df[df['rate']  > '3.1']
#comparison including both rate and votes was showcasing error
df[(df['listed_in(type)'] == 'Dining') & (df['book_table']=='Yes')] #checking multiple conditons
#dataTypes are crucial during comparison
# Out:
#                name online_order book_table   rate  votes  \
# 61         Goa 0 Km          Yes        Yes  3.6/5    163
# 63  Jeet Restaurant           No        Yes  4.0/5    808
#
#     approx_cost(for two people) listed_in(type)
# 61                          800          Dining
# 63                          850          Dining

# %%
df.sort_values("votes",ascending= False ) # for descending order
df.sort_values("votes") #for ascending order
# Out:
#                     name online_order book_table   rate  votes  \
# 110  Hari Super Sandwich           No         No  3.2/5      0
# 107        Coffee Shopee           No         No  3.4/5      0
# 117         Kulfi & More           No         No  3.4/5      0
# 118  Kannadigas Karavali           No         No  3.4/5      0
# 116           Wood Stove           No         No  3.4/5      0
# ..                   ...          ...        ...    ...    ...
# 65           Kabab Magic          Yes         No  4.1/5   1720
# 44                Onesta          Yes        Yes  4.6/5   2556
# 7                 Onesta          Yes        Yes  4.6/5   2556
# 86         Meghana Foods          Yes         No  4.4/5   4401
# 38     Empire Restaurant          Yes         No  4.4/5   4884
#
#      approx_cost(for two people) listed_in(type)
# 110                          200          Dining
# 107                          250          Dining
# 117                          150          Dining
# ...

# %%
df.rename(columns={"name" : "customer"}) #renaming any partcular column
df.rename(columns={"name" : "customer"} ,inplace = True) #renaming any partcular column and fixing it
#but not displaying anything for line 2

# %%
df.isnull().sum()
# to check if any null or zero value exists . sum() calculates the total number of times it occcured
df['votes'].isnull().sum()
#checking for a specific column
# Out:
# np.int64(0)

# %%
data = {"Roll_no." : [34,35,36,37],
        "Name ":["Anuj","Bablu","Chintu","Doxy"],
         "CGPA ":[9.0,7.8,8.9,8.8],
         "Placed ":["Yes","Yes", "Yes","Yes"]}
dff= pd.DataFrame(data)
print(dff)
# Out:
#    Roll_no.   Name   CGPA  Placed
# 0        34    Anuj    9.0     Yes
# 1        35   Bablu    7.8     Yes
# 2        36  Chintu    8.9     Yes
# 3        37    Doxy    8.8     Yes

# %%
dff.head() #showcasing the data frames
# Out:
#    Roll_no.   Name   CGPA  Placed
# 0        34    Anuj    9.0     Yes
# 1        35   Bablu    7.8     Yes
# 2        36  Chintu    8.9     Yes
# 3        37    Doxy    8.8     Yes

# %%
dff.head(3) #displays only 3 rows
# Out:
#    Roll_no.   Name   CGPA  Placed
# 0        34    Anuj    9.0     Yes
# 1        35   Bablu    7.8     Yes
# 2        36  Chintu    8.9     Yes

# %%
dff.describe() # displays statistical analyzed data of provied numeric values
# Out:
#         Roll_no.     CGPA
# count   4.000000  4.000000
# mean   35.500000  8.625000
# std     1.290994  0.556028
# min    34.000000  7.800000
# 25%    34.750000  8.550000
# 50%    35.500000  8.850000
# 75%    36.250000  8.925000
# max    37.000000  9.000000

# %%
dff.sample() #randomly displays a row
dff.sample(2) # randomly selects and displays rows as mentioned in index
# Out:
#    Roll_no.   Name   CGPA  Placed
# 1        35   Bablu    7.8     Yes
# 2        36  Chintu    8.9     Yes

# %%
dff.dtypes # highlights the dataType of each column
# Out:
# Roll_no.      int64
# Name         object
# CGPA        float64
# Placed       object
# dtype: object

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Roll_no.  4 non-null      int64
#  1   Name      4 non-null      object
#  2   CGPA      4 non-null      float64
#  3   Placed    4 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 260.0+ bytes
